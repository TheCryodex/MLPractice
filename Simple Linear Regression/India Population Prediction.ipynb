# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split
import numpy as np

#Reading CSV
df = pd.read_csv("Indiapop.csv")
year = df['YEAR']
pop  = df["POPULATION"]

#Plotting a graph
plt.xlabel("YEAR")
plt.ylabel("POPULATION (BILLION)")
plt.scatter(df['YEAR'],df['POPULATION'],marker = ".", color='red')
plt.plot(df['YEAR'],rg.predict(df[['YEAR']]))

#Training and Testing
rg = linear_model.LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(df[['YEAR']], df[["POPULATION"]], random_state = 12)

rg.fit(X_train, y_train)

rg.score(X_test, y_test)
rg.predict([[2020]])
# Out:
# array([[1.37860241e+09]])
